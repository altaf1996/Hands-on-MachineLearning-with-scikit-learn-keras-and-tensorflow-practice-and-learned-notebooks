# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
plt.figure(figsize=(12,12))

n_samples = 1500*2
random_state = 42
X, y = make_blobs(n_samples=n_samples, random_state=random_state)
print(f"Value Of X :{X}")
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)
print(f"Predictions for KMeans: {y_pred}")

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("KMEans")
# Out:
# Value Of X :[[-6.39232195 -5.80817973]
#  [-2.46538615  8.86728413]
#  [-3.87607632  8.78952073]
#  ...
#  [-6.73379072 -6.29481016]
#  [-7.08026649 -6.51259918]
#  [-6.54126975 -7.8726876 ]]
# Predictions for KMeans: [1 0 0 ... 1 1 1]
# Text(0.5, 1.0, 'KMEans')

# %%
plt.figure(figsize=(12,12))

n_samples = 1500*2
random_state = 42
X, y = make_blobs(n_samples=n_samples, random_state=random_state)
print(f"Value Of X :{X}")
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X)
print(f"Predictions for KMeans: {y_pred}")

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("KMEans")
# Out:
# Value Of X :[[-6.39232195 -5.80817973]
#  [-2.46538615  8.86728413]
#  [-3.87607632  8.78952073]
#  ...
#  [-6.73379072 -6.29481016]
#  [-7.08026649 -6.51259918]
#  [-6.54126975 -7.8726876 ]]
# Predictions for KMeans: [1 0 0 ... 1 1 1]
# Text(0.5, 1.0, 'KMEans')

# %%
y_pred[:20]
# Out:
# array([1, 0, 0, 0, 2, 0, 2, 2, 1, 2, 1, 0, 0, 0, 1, 0, 2, 0, 0, 1])

# %%
plt.figure(figsize=(12,12))

n_samples = 1500
random_state = 42
X, y = make_blobs(n_samples=n_samples, random_state=random_state)
print(f"Value Of X :{X}")
kmeans = KMeans(n_clusters=3,random_state=random_state)
y_pred = kmeans.fit_predict(X)
print(f"Predictions for KMeans: {y_pred}")

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("KMEans")
# Out:
# Value Of X :[[ 4.50557009  2.78397796]
#  [-7.11002791 -7.80434274]
#  [-6.37976307 -8.27941577]
#  ...
#  [ 6.65326608  2.10970502]
#  [-6.65431927 -7.24963652]
#  [ 6.52446514  3.51641321]]
# Predictions for KMeans: [2 1 1 ... 2 1 2]
# Text(0.5, 1.0, 'KMEans')

# %%
kmeans.labels_
# Out:
# array([2, 1, 1, ..., 2, 1, 2])

# %%
kmeans.n_clusters
# Out:
# 3

# %%
kmeans.cluster_centers_
# Out:
# array([[-2.5031025 ,  9.04839015],
#        [-6.88666421, -6.85834942],
#        [ 4.69161308,  2.05025033]])

# %%
X_new = np.array([[0,2], [3,2], [-3,3], [-3,2.5]])
X_new.ndim
# Out:
# 2

# %%
plt.scatter(X_new[:,0],X_new[:,1])

# %%
new_preds = kmeans.predict(X_new)
new_preds
# Out:
# array([2, 2, 0, 0])

# %%
plt.figure(figsize=(12,12))
plt.subplot(221)
plt.scatter(X_new[:,0],X_new[:,1], c=new_preds)

# %%
kmeans.transform(X_new)
# Out:
# array([[ 7.47966081, 11.22036089,  4.69188218],
#        [ 8.94225591, 13.27465569,  1.69235927],
#        [ 6.0687668 , 10.59684916,  7.75002814],
#        [ 6.56721559, 10.13335397,  7.70475091]])

# %%
kmeans.inertia_
# Out:
# 2925.388508444432

# %%
kmeans.score(X_new)
# Out:
# -104.83608944822319

# %%
from sklearn.cluster import MiniBatchKMeans

minibatch_kmeans = MiniBatchKMeans(n_clusters=3)
minibatch_kmeans.fit(X)
# Out:
# MiniBatchKMeans(n_clusters=3)

# %%
y_preds = minibatch_kmeans.predict(X_new)
y_preds
# Out:
# array([2, 2, 1, 1])

# %%
minibatch_kmeans.transform(X_new)
# Out:
# array([[11.14984863,  7.52224534,  4.67602307],
#        [13.20896279,  8.97420427,  1.67620345],
#        [10.52338642,  6.11858505,  7.74481279],
#        [10.05990092,  6.61698915,  7.69424625]])

# %%
minibatch_kmeans.inertia_
# Out:
# 2932.751836440806

# %%
minibatch_kmeans.score(X_new)
# Out:
# -105.89647812401162

# %%
from sklearn.metrics import silhouette_score

silhouette_score(X, kmeans.labels_)
# Out:
# 0.8433650914680958

# %%
labels = []
for i in np.arange(2,10):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(np.array(X).astype("int8"))
    #silhouette_score(X, kmeans.labels_)
    labels.append(kmeans.labels_)

# %%
len(labels[0]), len(labels[7])
# Out:
# (1500, 1500)

# %%
kmeans.labels_
# Out:
# array([0, 1, 1, ..., 6, 1, 6])
